# %% [markdown]
# <a href="https://colab.research.google.com/github/KodaliSuchitraKamala/CodeAlpha_Web_Scarping/blob/main/WebScarping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧠 Web Scraping with Python in Google Colab
# 📌 Section 1: Introduction
from IPython.display import Markdown

# %% [markdown]
# """
# # 🔍 Web Scraping with Python
#
# The internet is filled with excellent (and free) public datasets, but the ability to find and extract relevant data yourself is a crucial skill for any data analyst.
#
# Using Python, you can leverage tools like **BeautifulSoup** or **Scrapy** to crawl the web for valuable data.
# If you don't know how to code, tools like **Octoparse** or **ParseHub** offer automated solutions (many with free trials).
#
# > Mastering web scraping allows you to work with customized datasets that align with your specific interests—even if they haven't been pre-compiled.
# """

# %%
# 📌 Section 2: Install and Import Required Libraries
# !pip install requests beautifulsoup4

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 📌 Section 3: Scraping Example – Get Book Titles and Prices

url = 'http://books.toscrape.com/'

# Send a GET request
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract book titles and prices
books = soup.find_all('article', class_='product_pod')

titles = []
prices = []

for book in books:
    title = book.h3.a['title']
    price = book.find('p', class_='price_color').text
    titles.append(title)
    prices.append(price)

# Display results
df = pd.DataFrame({'Title': titles, 'Price': prices})
df.head()
# Out:
#                                    Title    Price
# 0                   A Light in the Attic  Â£51.77
# 1                     Tipping the Velvet  Â£53.74
# 2                             Soumission  Â£50.10
# 3                          Sharp Objects  Â£47.82
# 4  Sapiens: A Brief History of Humankind  Â£54.23
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('Title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_13.groupby('Price').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Price'].value_counts()
    for x_label, grp in _df_14.groupby('Title')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Title')
_ = plt.ylabel('Price')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_13.groupby('Price').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_12.groupby('Title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# 📌 Section 4: Save to CSV
df.to_csv('books.csv', index=False)
print("✅ Data saved to books.csv")
# Out:
# ✅ Data saved to books.csv

# %% [markdown]
# # 📌 Section 5: Summary & No-Code Alternatives
#
# ### 📝 Summary
#
# - We scraped book titles and prices from [books.toscrape.com](http://books.toscrape.com)
# - Used `requests` for making HTTP requests
# - Used `BeautifulSoup` for parsing HTML
#
# ---
#
# ### ⚙️ No-Code Alternatives
#
# If you're not a coder, try:
#
# - **[Octoparse](https://www.octoparse.com/)** – Visual point-and-click scraping tool
# - **[ParseHub](https://www.parsehub.com/)** – Easy setup with powerful configuration
#
# These tools offer free plans and are great for beginners.
#
# ---
